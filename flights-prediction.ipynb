# %%
import pandas
import warnings

warnings.simplefilter('ignore')

researched_country = 'Poland'

# %%
arrivals2020 = pandas.read_csv('raw_data/raw_arrivals_data/arrivals_2020.csv')
arrivals2021 = pandas.read_csv('raw_data/raw_arrivals_data/arrivals_2021.csv')

arrivals_data = arrivals2020.append(arrivals2021, ignore_index=True)

arrivals_data
# Out:
#         YEAR  MONTH_NUM MONTH_MON              FLT_DATE APT_ICAO  \
# 0       2020          1       JAN  2020-01-01T00:00:00Z     LFRS
# 1       2020          1       JAN  2020-01-01T00:00:00Z     EDDL
# 2       2020          1       JAN  2020-01-01T00:00:00Z     LGZA
# 3       2020          1       JAN  2020-01-01T00:00:00Z     LIME
# 4       2020          1       JAN  2020-01-01T00:00:00Z     LGMK
# ...      ...        ...       ...                   ...      ...
# 192932  2021         12       DEC  2021-12-31T00:00:00Z     LFRO
# 192933  2021         12       DEC  2021-12-31T00:00:00Z     UDYZ
# 192934  2021         12       DEC  2021-12-31T00:00:00Z     ESSB
# 192935  2021         12       DEC  2021-12-31T00:00:00Z     EIDL
# 192936  2021         12       DEC  2021-12-31T00:00:00Z     GEML
#
#                  APT_NAME STATE_NAME  FLT_ARR_1  DLY_APT_ARR_1  \
# 0       Nantes-Atlantique     France         62            NaN
# 1              Dusseldorf    Germany        190            NaN
# 2               Zakinthos     Greece          1            NaN
# 3                 Bergamo      Italy        107            NaN
# 4                 Mikonos     Greece          4            NaN
# ...                   ...        ...        ...            ...
# 192932            Lannion     France          1            NaN
# 192933          Zvartnots    Armenia         25            NaN
# 192934  Stockholm/ Bromma     Sweden          0            NaN
# 192935            Donegal    Ireland          2            NaN
# 192936            Melilla      Spain          5            NaN
#
#         DLY_APT_ARR_A_1  ...  DLY_APT_ARR_P_1  DLY_APT_ARR_R_1  \
# 0                   NaN  ...              NaN              NaN
# 1                   NaN  ...              NaN              NaN
# 2                   NaN  ...              NaN              NaN
# 3                   NaN  ...              NaN              NaN
# 4                   NaN  ...              NaN              NaN
# ...                 ...  ...              ...              ...
# 192932              NaN  ...              NaN              NaN
# 192933              NaN  ...              NaN              NaN
# 192934              NaN  ...              NaN              NaN
# 192935              NaN  ...              NaN              NaN
# 192936              NaN  ...              NaN              NaN
#
#         DLY_APT_ARR_S_1  DLY_APT_ARR_T_1  DLY_APT_ARR_V_1  DLY_APT_ARR_W_1  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 192932              NaN              NaN              NaN              NaN
# 192933              NaN              NaN              NaN              NaN
# 192934              NaN              NaN              NaN              NaN
# 192935              NaN              NaN              NaN              NaN
# 192936              NaN              NaN              NaN              NaN
#
#         DLY_APT_ARR_NA_1  FLT_ARR_1_DLY  FLT_ARR_1_DLY_15  ATFM_VERSION
# 0                    NaN            NaN               NaN            v2
# 1                    NaN            NaN               NaN            v2
# 2                    NaN            NaN               NaN            v2
# 3                    NaN            NaN               NaN            v2
# 4                    NaN            NaN               NaN            v2
# ...                  ...            ...               ...           ...
# 192932               NaN            NaN               NaN            v2
# 192933               NaN            NaN               NaN            v2
# 192934               NaN            NaN               NaN            v2
# 192935               NaN            NaN               NaN            v2
# 192936               NaN            NaN               NaN            v2
#
# [192937 rows x 28 columns]

# %%
arrivals_data = arrivals_data.filter(["FLT_DATE", "APT_NAME", "STATE_NAME", "FLT_ARR_1"])

arrivals_data
# Out:
#                     FLT_DATE           APT_NAME STATE_NAME  FLT_ARR_1
# 0       2020-01-01T00:00:00Z  Nantes-Atlantique     France         62
# 1       2020-01-01T00:00:00Z         Dusseldorf    Germany        190
# 2       2020-01-01T00:00:00Z          Zakinthos     Greece          1
# 3       2020-01-01T00:00:00Z            Bergamo      Italy        107
# 4       2020-01-01T00:00:00Z            Mikonos     Greece          4
# ...                      ...                ...        ...        ...
# 192932  2021-12-31T00:00:00Z            Lannion     France          1
# 192933  2021-12-31T00:00:00Z          Zvartnots    Armenia         25
# 192934  2021-12-31T00:00:00Z  Stockholm/ Bromma     Sweden          0
# 192935  2021-12-31T00:00:00Z            Donegal    Ireland          2
# 192936  2021-12-31T00:00:00Z            Melilla      Spain          5
#
# [192937 rows x 4 columns]

# %%
arrivals_data = arrivals_data.drop(arrivals_data[arrivals_data['STATE_NAME'] != researched_country].index)

arrivals_data
# Out:
#                     FLT_DATE              APT_NAME STATE_NAME  FLT_ARR_1
# 15      2020-01-01T00:00:00Z  Wroclaw/ Strachowice     Poland         28
# 22      2020-01-01T00:00:00Z        Olsztyn-Mazury     Poland          4
# 47      2020-01-01T00:00:00Z  Katowice - Pyrzowice     Poland         29
# 50      2020-01-01T00:00:00Z     Warszawa/ Chopina     Poland        203
# 69      2020-01-01T00:00:00Z       Poznan - Lawica     Poland         14
# ...                      ...                   ...        ...        ...
# 192866  2021-12-31T00:00:00Z        Olsztyn-Mazury     Poland          1
# 192889  2021-12-31T00:00:00Z  Wroclaw/ Strachowice     Poland         24
# 192896  2021-12-31T00:00:00Z                Lublin     Poland          2
# 192902  2021-12-31T00:00:00Z    Rzeszow - Jasionka     Poland          4
# 192926  2021-12-31T00:00:00Z             Bydgoszcz     Poland          2
#
# [9337 rows x 4 columns]

# %%
data_arrival_dict = dict()

for index, row in arrivals_data.iterrows():
    date = row['FLT_DATE'][0:10]
    arrivals = row["FLT_ARR_1"]
    if date in data_arrival_dict:
        data_arrival_dict[date] += arrivals
    else:
        data_arrival_dict[date] = arrivals

arrivals_data = pandas.DataFrame(data_arrival_dict.items(), columns=['date', 'arrivals'])

arrivals_data['date'] = pandas.to_datetime(arrivals_data['date'])


arrivals_data, arrivals_data.plot(x = 'date')
# Out:
# (          date  arrivals
#  0   2020-01-01       452
#  1   2020-01-02       622
#  2   2020-01-03       602
#  3   2020-01-04       487
#  4   2020-01-05       566
#  ..         ...       ...
#  726 2021-12-27       517
#  727 2021-12-28       429
#  728 2021-12-29       429
#  729 2021-12-30       452
#  730 2021-12-31       379
#
#  [731 rows x 2 columns],
#  <AxesSubplot:xlabel='date'>)

# %%
covid_data = pandas.read_csv('raw_data/covid_data_raw.csv')

covid_data
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 138936      ZWE    Africa     Zimbabwe  2021-12-05     139046.0      523.0
# 138937      ZWE    Africa     Zimbabwe  2021-12-06     139046.0        0.0
# 138938      ZWE    Africa     Zimbabwe  2021-12-07     141601.0     2555.0
# 138939      ZWE    Africa     Zimbabwe  2021-12-08     150628.0     9027.0
# 138940      ZWE    Africa     Zimbabwe  2021-12-09     155817.0     5189.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 138936             727.857        4710.0         1.0                0.714
# 138937             688.571        4710.0         0.0                0.571
# 138938             996.571        4713.0         3.0                0.857
# 138939            2184.429        4720.0         7.0                1.857
# 138940            2776.857        4723.0         3.0                2.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 138936  ...             1.6          30.7                  36.791
# 138937  ...             1.6          30.7                  36.791
# 138938  ...             1.6          30.7                  36.791
# 138939  ...             1.6          30.7                  36.791
# 138940  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 138936                         1.7            61.49                    0.571
# 138937                         1.7            61.49                    0.571
# 138938                         1.7            61.49                    0.571
# 138939                         1.7            61.49                    0.571
# 138940                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 138936                                   NaN                          NaN
# 138937                                   NaN                          NaN
# 138938                                   NaN                          NaN
# 138939                                   NaN                          NaN
# 138940                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 138936               NaN                                      NaN
# 138937               NaN                                      NaN
# 138938               NaN                                      NaN
# 138939               NaN                                      NaN
# 138940               NaN                                      NaN
#
# [138941 rows x 67 columns]

# %%
covid_data = covid_data.filter(['location', 'date', 'new_cases'])

covid_data
# Out:
#            location        date  new_cases
# 0       Afghanistan  2020-02-24        5.0
# 1       Afghanistan  2020-02-25        0.0
# 2       Afghanistan  2020-02-26        0.0
# 3       Afghanistan  2020-02-27        0.0
# 4       Afghanistan  2020-02-28        0.0
# ...             ...         ...        ...
# 138936     Zimbabwe  2021-12-05      523.0
# 138937     Zimbabwe  2021-12-06        0.0
# 138938     Zimbabwe  2021-12-07     2555.0
# 138939     Zimbabwe  2021-12-08     9027.0
# 138940     Zimbabwe  2021-12-09     5189.0
#
# [138941 rows x 3 columns]

# %%
covid_data = covid_data.drop(covid_data[covid_data['location'] != researched_country].index)
covid_data['new_cases'] = covid_data['new_cases'].astype(int)

covid_data
# Out:
#        location        date  new_cases
# 100382   Poland  2020-03-04          1
# 100383   Poland  2020-03-05          0
# 100384   Poland  2020-03-06          4
# 100385   Poland  2020-03-07          0
# 100386   Poland  2020-03-08          6
# ...         ...         ...        ...
# 101023   Poland  2021-12-05      22394
# 101024   Poland  2021-12-06      13250
# 101025   Poland  2021-12-07      19369
# 101026   Poland  2021-12-08      28549
# 101027   Poland  2021-12-09      27459
#
# [646 rows x 3 columns]

# %%
covid_data['date'] = pandas.to_datetime(covid_data['date'])

covid_data.plot(x = 'date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
covid_data = covid_data.drop('location', 1)

merged_data = arrivals_data.merge(covid_data, on='date')

merged_data
# Out:
#           date  arrivals  new_cases
# 0   2020-03-04       558          1
# 1   2020-03-05       585          0
# 2   2020-03-06       614          4
# 3   2020-03-07       488          0
# 4   2020-03-08       537          6
# ..         ...       ...        ...
# 641 2021-12-05       409      22394
# 642 2021-12-06       466      13250
# 643 2021-12-07       396      19369
# 644 2021-12-08       431      28549
# 645 2021-12-09       426      27459
#
# [646 rows x 3 columns]

# %%
merged_data.plot(x = 'date', y = 'new_cases')
merged_data.plot(x = 'date', y = 'arrivals')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
complete_data = merged_data.drop('date', axis=1)
complete_data.index = merged_data['date']

complete_data
# Out:
#             arrivals  new_cases
# date
# 2020-03-04       558          1
# 2020-03-05       585          0
# 2020-03-06       614          4
# 2020-03-07       488          0
# 2020-03-08       537          6
# ...              ...        ...
# 2021-12-05       409      22394
# 2021-12-06       466      13250
# 2021-12-07       396      19369
# 2021-12-08       431      28549
# 2021-12-09       426      27459
#
# [646 rows x 2 columns]

# %%
data_split_coefficient = 0.9

train = complete_data[:int(data_split_coefficient * (len(complete_data)))]

train
# Out:
#             arrivals  new_cases
# date
# 2020-03-04       558          1
# 2020-03-05       585          0
# 2020-03-06       614          4
# 2020-03-07       488          0
# 2020-03-08       537          6
# ...              ...        ...
# 2021-10-01       521       1361
# 2021-10-02       421       1344
# 2021-10-03       466       1090
# 2021-10-04       505        683
# 2021-10-05       407       1327
#
# [581 rows x 2 columns]

# %%
valid = complete_data[int(data_split_coefficient * (len(complete_data))):]

valid
# Out:
#             arrivals  new_cases
# date
# 2021-10-06       456       2086
# 2021-10-07       461       2007
# 2021-10-08       525       1894
# 2021-10-09       395       2011
# 2021-10-10       456       1527
# ...              ...        ...
# 2021-12-05       409      22394
# 2021-12-06       466      13250
# 2021-12-07       396      19369
# 2021-12-08       431      28549
# 2021-12-09       426      27459
#
# [65 rows x 2 columns]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX 
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt

def SARIMAX_model(train):
    model = SARIMAX(endog=train.drop('new_cases', axis=1), exog=train['new_cases'])
    model_fit = model.fit()

    return model_fit

test_model = SARIMAX_model(train)

result = test_model.forecast(steps=len(valid), exog=valid['new_cases'])

predicted_arrivals = pandas.DataFrame(result)

predicted_arrivals.plot()
valid['arrivals'].plot()
plt.legend(["predicted_arrivals_mean", "actual_arrivals"])

rmse = math.sqrt(mean_squared_error(predicted_arrivals["predicted_mean"], valid["arrivals"]))
print(f'rmse: {rmse}')
# Out:
# /home/dmitriy/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /home/dmitriy/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /home/dmitriy/.local/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# rmse: 126.55694691981958

# %%
future_covid_data = covid_data.drop(covid_data[covid_data['date'] <= arrivals_data['date'].iat[-1]].index)

exog_covid = future_covid_data.drop('date', axis=1)
exog_covid.index = future_covid_data['date']

prediction_model = SARIMAX_model(complete_data)

result = prediction_model.forecast(steps=len(exog_covid), exog = exog_covid)


prediction = pandas.DataFrame(result)

prediction.plot()
plt.legend(["predicted_arrivals_mean"])
exog_covid.plot()

# update train data until the first day of forecast
# Out:
# /home/dmitriy/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /home/dmitriy/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_20527/4080363905.py in <module>
#       6 prediction_model = SARIMAX_model(complete_data)
#       7
# ----> 8 result = prediction_model.forecast(steps=len(exog_covid), exog = exog_covid)
#       9
#      10
#
# ~/.local/lib/python3.8/site-packages/statsmodels/base/wrapper.py in wrapper(self, *args, **kwargs)
#     111             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#     112         elif how:
# --> 113             obj = data.wrap_output(func(results, *args, **kwargs), how)
#     114         return obj
#     115
#
# ~/.local/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in forecast(self, steps, **kwargs)
#    3395         else:
#    3396             end = steps
# -> 3397         return self.predict(start=self.nobs, end=end, **kwargs)
#    3398
#    3399     def simulate(self, nsimulations, measurement_shocks=None,
#
# ~/.local/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in predict(self, start, end, dynamic, **kwargs)
#    3367         """
#    3368         # Perform the prediction
# -> 3369         prediction_results = self.get_prediction(start, end, dynamic, **kwargs)
#    3370         return prediction_results.predicted_mean
#    3371
#
# ~/.local/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in get_prediction(self, start, end, dynamic, index, exog, extend_model, extend_kwargs, **kwargs)
#    3265         # Handle start, end, dynamic
#    3266         start, end, out_of_sample, prediction_index = (
# -> 3267             self.model._get_prediction_index(start, end, index))
#    3268
#    3269         # Handle `dynamic`
#
# ~/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in _get_prediction_index(self, start, end, index, silent)
#     748         """
#     749         nobs = len(self.endog)
# --> 750         return get_prediction_index(start,
#     751                                     end,
#     752                                     nobs,
#
# ~/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     359     # Validate prediction options
#     360     if end < start:
# --> 361         raise ValueError('Prediction must have `end` after `start`.')
#     362
#     363     # Handle custom prediction index
#
# ValueError: Prediction must have `end` after `start`.

# %%
def process_forecast_data(file_location):
    import pandas as pd
    df = pd.read_csv(file_location)

    # remove death records
    df = df[~df.target.str.contains("death")]

    # remove quntile records
    df = df[df.type == 'point']

    forecast_date = df.forecast_date[0]

    df = df.drop(['forecast_date', 'target', 'location', 'quantile', 'scenario_id', 'type'], 1).reset_index(drop=True).rename(columns={'target_end_date': 'date'})

    df.date = pd.to_datetime(df.date)
    # df.plot(x = 'date')
    df.index = df.date
    df = df.drop('date', 1)

    df = df.reindex(pd.date_range(df.index[0],df.index[-1],freq='D'))
    df = df.interpolate(method='quadratic')
    df.value = df.value.astype(int)

    return df

covid_forecast = process_forecast_data('raw_data/2022-01-24-ICM-agentModel.csv')

result = prediction_model.forecast(steps=len(covid_forecast), exog=covid_forecast)

prediction = pandas.DataFrame(result) 

prediction.plot()
covid_forecast.plot()
# Out:
# <AxesSubplot:>
